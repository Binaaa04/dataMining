# %% [markdown]
# <a href="https://colab.research.google.com/github/Binaaa04/dataMining/blob/main/JS9_Reggresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#menampilkan data 5 teratas dari file csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
print("pustaka success imported!")
url_data = '/content/harga_mobil_bekas.csv'
try:
  df = pd.read_csv(url_data)
  print("dataset success imported!")
  print("five top row : ")
  display(df.head())

except Exception as e :
  print(f"dataset failed imported!.Error: {e}")
  print("make sure the dataset url or file has been uploaded")
# Out:
# pustaka success imported!
# dataset success imported!
# five top row :
#       Merek   Model  Tahun  JarakTempuh  UkuranMesin  Transmisi  Harga
# 0    Toyota  Avanza   2018        75000         1300     Manual    145
# 1     Honda    Brio   2019        60000         1200  Automatic    155
# 2    Suzuki  Ertiga   2017        90000         1500     Manual    130
# 3    Toyota  Innova   2016       110000         2000  Automatic    240
# 4  Daihatsu   Xenia   2019        65000         1300     Manual    140

# %%
#Eksplorasi Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)
print("\n dataset information:")
df.info()
print("\n statistic description:")
display(df.describe())
year = 2025
df['Usia'] = year - df['Tahun']
print("\n 'Usia'column success added")
display(df[['Tahun','Usia','Harga']].head())
print("\n check missing value:")
display(df.isnull().sum())

plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Usia',y='Harga')
plt.title('relation car age with price' )
plt.xlabel('Car Age')
plt.ylabel('Price (in IDR)')
plt.grid(True)
plt.show()
# Out:
#  dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Merek        72 non-null     object
#  1   Model        72 non-null     object
#  2   Tahun        72 non-null     int64
#  3   JarakTempuh  72 non-null     int64
#  4   UkuranMesin  72 non-null     int64
#  5   Transmisi    72 non-null     object
#  6   Harga        72 non-null     int64
# dtypes: int64(4), object(3)
# memory usage: 4.1+ KB
#
#  statistic description:
#              Tahun    JarakTempuh  UkuranMesin        Harga
# count    72.000000      72.000000    72.000000    72.000000
# mean   2018.763889   66930.555556  1545.833333   238.513889
# std       1.989359   33165.537174   406.959700   176.695010
# min    2015.000000   10000.000000  1000.000000    80.000000
# 25%    2017.000000   40000.000000  1300.000000   133.750000
# ...

# %%
# PRATIKKUM SIMPLE LINEAR REGGRESION
#menyiapkan data utk simple linear regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
X_slr = df['Usia']
y = df['Harga']
print("Fitur (X) utk SLR:")
display(X_slr.head())
print("\nTarget (y):")
display(y.head())
# Out:
# Fitur (X) utk SLR:
# 0    7
# 1    6
# 2    8
# 3    9
# 4    6
# Name: Usia, dtype: int64
# Target (y):
# 0    145
# 1    155
# 2    130
# 3    240
# 4    140
# Name: Harga, dtype: int64

# %%
#pembagian data training (80%) dan data testing (20%)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
X_slr = df[['Usia']]
y = df['Harga']

X_train_slr, X_test_slr, y_train, y_test = train_test_split(X_slr, y, test_size=0.2, random_state=42)
print("data train shape X:", X_train_slr.shape)
print("test data shape X:", X_test_slr.shape)
print("data train shape y:", y_train.shape)
print("test data shape y:", y_test.shape)
# Out:
# data train shape X: (57, 1)
# test data shape X: (15, 1)
# data train shape y: (57,)
# test data shape y: (15,)

# %%
# membangun model SLR dan melatih model SLR menggunakan data training
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
X_slr = df[['Usia']]
y = df['Harga']

X_train_slr, X_test_slr, y_train, y_test = train_test_split(X_slr, y, test_size=0.2, random_state=42)
model_slr = LinearRegression()
model_slr.fit(X_train_slr, y_train)
print("model success trained!")
# Out:
# model success trained!

# %%
#mengindetifikasikan parameter model SLR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
X_slr = df[['Usia']]
y = df['Harga']

X_train_slr, X_test_slr, y_train, y_test = train_test_split(X_slr, y, test_size=0.2, random_state=42)
model_slr = LinearRegression()
model_slr.fit(X_train_slr, y_train)
intercept_slr = model_slr.intercept_
coef_slr = model_slr.coef_[0]
print(f"intercept (βo):, {intercept_slr:.2f}")
print(f"coefficient(β1):, {coef_slr:.2f}")
print(f"\nInterpretation : ")
print(f"the model predicts the base price of the car (0 years old) to be around {intercept_slr:.2f} Million Rupiahs")
print(f"for every additional 1 year of age, the price of the car is predicted to decrease by {abs(coef_slr):.2f} millions rupiahs")
# Out:
# intercept (βo):, 363.71
# coefficient(β1):, -19.36
#
# Interpretation :
# the model predicts the base price of the car (0 years old) to be around 363.71 Million Rupiahs
# for every additional 1 year of age, the price of the car is predicted to decrease by 19.36 millions rupiahs

# %%
#evakuasi model SLR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
X_slr = df[['Usia']]
y = df['Harga']

X_train_slr, X_test_slr, y_train, y_test = train_test_split(X_slr, y, test_size=0.2, random_state=42)
model_slr = LinearRegression()
model_slr.fit(X_train_slr, y_train)
y_pred_slr = model_slr.predict(X_test_slr)
mae_slr = mean_absolute_error(y_test, y_pred_slr)
mse_slr = mean_squared_error(y_test, y_pred_slr)
rmse_slr = np.sqrt(mse_slr)
r2_slr = r2_score(y_test, y_pred_slr)
print("\nEvaluation metrics for SLR model in test data:")
print(f"Mean Absolute Error (MAE):, {mae_slr:.2f} millions rupiahs")
print(f"Mean Squared Error (MSE):, {mse_slr:.2f}")
print(f"Root Mean Squared Error (RMSE):, {rmse_slr:.2f} millions rupiah")
print(f"R-squared (R2):, {r2_slr:.2f}")

#bandingkan dgn target
print("\ncompare with target :")
print(f"Target R kuadrat > 0.5 : {'accomplished' if r2_slr > 0.5 else 'not accomplished'}")
print(f"Target MAE > 0.5 : {'accomplished' if mae_slr > 30 else 'not accomplished'}")
# Out:
# Evaluation metrics for SLR model in test data:
# Mean Absolute Error (MAE):, 78.31 millions rupiahs
# Mean Squared Error (MSE):, 7835.10
# Root Mean Squared Error (RMSE):, 88.52 millions rupiah
# R-squared (R2):, -0.04
#
# compare with target :
# Target R kuadrat > 0.5 : not accomplished
# Target MAE > 0.5 : accomplished

# %%
#visualisasi hasil prediksi (SLR)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
X_slr = df[['Usia']]
y = df['Harga']

X_train_slr, X_test_slr, y_train, y_test = train_test_split(X_slr, y, test_size=0.2, random_state=42)
model_slr = LinearRegression()
model_slr.fit(X_train_slr, y_train)
y_pred_slr = model_slr.predict(X_test_slr)
mae_slr = mean_absolute_error(y_test, y_pred_slr)
mse_slr = mean_squared_error(y_test, y_pred_slr)
rmse_slr = np.sqrt(mse_slr)
r2_slr = r2_score(y_test, y_pred_slr)

plt.figure(figsize=(10, 6))
plt.scatter(X_test_slr, y_test, alpha = 0.7, label='Actual data')
plt.plot(X_test_slr, y_pred_slr, color='red', linewidth=2, label='Predicted line')
plt.title('Result Prediction SLR : Price vs Car Age (Test Data)')
plt.xlabel('Car Age')
plt.ylabel('Price (in IDR)')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(x=y_test, y=y_pred_slr)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Prediction Price (SLR)')
plt.xlabel('Actual Price (in IDR)')
plt.ylabel('Predicted Price (in IDR)')

plt.grid(True)
plt.show()

# %%
#PRAKTIKKUM MULTIPLE LINEAR REGRESSION
# persiapan data utk MLR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk MLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
print("\n'Usia' column success added")
features_mlr = ['JarakTempuh','Usia','UkuranMesin']
X_mlr = df[features_mlr]
#y = df['Harga']
print("\nFeatures (X) for MLR:")
display(X_mlr.head())
# Out:
# 'Usia' column success added
#
# Features (X) for MLR:
#    JarakTempuh  Usia  UkuranMesin
# 0        75000     7         1300
# 1        60000     6         1200
# 2        90000     8         1500
# 3       110000     9         2000
# 4        65000     6         1300

# %%
#membagi data training dan data testing (MLR)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
features_mlr = ['JarakTempuh','Usia','UkuranMesin']
X_mlr = df[features_mlr]
#y = df['Harga']
X_train_mlr, X_test_mlr, y_train, y_test = train_test_split(X_mlr, y, test_size=0.2, random_state=42)
print(f"data train shape X_mlr: {X_train_mlr.shape}")
print(f"test data shape X_mlr: {X_test_mlr.shape}")
# Out:
# data train shape X_mlr: (57, 3)
# test data shape X_mlr: (15, 3)

# %%
# melakukan pemeriksaan multikolinearitas (MLR)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
features_mlr = ['JarakTempuh','Usia','UkuranMesin']
X_mlr = df[features_mlr]
#y = df['Harga']
X_train_mlr, X_test_mlr, y_train, y_test = train_test_split(X_mlr, y, test_size=0.2, random_state=42)
correlation_matrix = X_train_mlr.corr()
print("\nCorrelation Matrix Feature : ")
display(correlation_matrix)
plt.figure(figsize=(7, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix for MLR')
plt.show()
# Out:
# Correlation Matrix Feature :
#              JarakTempuh      Usia  UkuranMesin
# JarakTempuh     1.000000  0.953996     0.071880
# Usia            0.953996  1.000000     0.173676
# UkuranMesin     0.071880  0.173676     1.000000

# %%
#Identifikasi parameter model MLR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
features_mlr = ['JarakTempuh','Usia','UkuranMesin']
X_mlr = df[features_mlr]
model_mlr = LinearRegression()
#y = df['Harga']
X_train_mlr, X_test_mlr, y_train, y_test = train_test_split(X_mlr, y, test_size=0.2, random_state=42)
correlation_matrix = X_train_mlr.corr()
intercept_mlr = model_mlr.intercept_
coeffs_mlr = model_mlr.coef_
print("\nintercept (βo):, {intercept_mlr:.2f}")
#tampilkan koefisien dlm dataframe agar mudah dibaca
coeffs_df = pd.DataFrame(coeffs_mlr, index=features_mlr, columns=['Koefisien (β)'])
print("\ncoefficient feature:")
display(coeffs_df)
print(f"\nInterpretation (example for 'Usia'): ")
print(f"assuming constant distance traveled and machine size,")
if 'Usia' in coeffs_df.index :
  usia_coef = coeffs_df.loc['Usia','Koefisien (β)']
  print(f"for every additional year of age, the price of the car is predicted to decrease by {usia_coef:.2f} millions rupiahs")
else:
  print("Usia coefficient not found in the model.")
# Out:
# intercept (βo): -215.20
#
# coefficient feature:
#              Koefisien (β)
# JarakTempuh      -0.007544
# Usia             90.991112
# UkuranMesin       0.254028
# Interpretation (example for 'Usia'):
# assuming constant distance traveled and machine size,
# for every additional year of age, the price of the car is predicted to decrease by 90.99 millions rupiahs

# %%
#Melakukan perbandingan SLR dan MLR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#fitur utk SLR hanya 'usia'
year = 2025
df['Usia'] = year - df['Tahun']
features_mlr = ['JarakTempuh','Usia','UkuranMesin']
X_train_mlr, X_test_mlr, y_train, y_test = train_test_split(X_mlr, y, test_size=0.2, random_state=42)
X_mlr = df[features_mlr]
model_mlr = LinearRegression()
model_mlr.fit(X_train_mlr, y_train)
y_pred_mlr = model_mlr.predict(X_test_mlr)
mae_mlr = mean_absolute_error(y_test, y_pred_mlr)
mse_mlr = mean_squared_error(y_test, y_pred_mlr)
rmse_mlr = np.sqrt(mse_mlr)
r2_mlr = r2_score(y_test, y_pred_mlr)

X_train_slr, X_test_slr, y_train, y_test = train_test_split(X_slr, y, test_size=0.2, random_state=42)
model_slr = LinearRegression()
model_slr.fit(X_train_slr, y_train)
y_pred_slr = model_slr.predict(X_test_slr)
mae_slr = mean_absolute_error(y_test, y_pred_slr)
mse_slr = mean_squared_error(y_test, y_pred_slr)
rmse_slr = np.sqrt(mse_slr)
r2_slr = r2_score(y_test, y_pred_slr)

print("\nPerbandingan Performa Model:")
print(f"{'':<15}| {'SLR (Usia)':<12}| {'MLR (Usia, Jarak, Mesin)'}")
print(f"{'-'*15}|{'-'*13}|{'-'*26}")
print(f"{'R²':<15}| {r2_slr:.3f}<12| {r2_mlr:.3f}")
print(f"{'MAE (Juta)':<15}| {mae_slr:.2f}<12| {mae_mlr:.2f}")
print(f"{'RMSE (Juta)':<15}| {rmse_slr:.2f}<12| {rmse_mlr:.2f}")

print("\nAnalisis:")
if r2_mlr > r2_slr and rmse_mlr < rmse_slr:
    print("Model MLR menunjukkan performa yang lebih baik daripada SLR.")
    print(f"Target R² > 0.5: {'Tercapai' if r2_mlr > 0.5 else 'Tidak Tercapai'}")
    print(f"Target MAE < 30: {'Tercapai' if mae_mlr < 30 else 'Tidak Tercapai'}")
else:
    print("Penambahan fitur pada MLR tidak secara signifikan meningkatkan performa dibandingkan SLR, atau bahkan memperburuk.")
    print("Perlu dianalisis lebih lanjut (mungkin ada multikolinearitas atau fitur tidak relevan).")

plt.figure(figsize=(8, 5))
sns.scatterplot(x=y_test, y=y_pred_mlr)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Aktual vs Prediksi Harga (MLR)')
plt.xlabel('Harga Aktual (Juta Rupiah)')
plt.ylabel('Harga Prediksi (Juta Rupiah)')
plt.grid(True)
plt.show()
# Out:
# Perbandingan Performa Model:
#                | SLR (Usia)  | MLR (Usia, Jarak, Mesin)
# ---------------|-------------|--------------------------
# R²             | -0.043<12| 0.748
# MAE (Juta)     | 78.31<12| 36.89
# RMSE (Juta)    | 88.52<12| 43.55
#
# Analisis:
# Model MLR menunjukkan performa yang lebih baik daripada SLR.
# Target R² > 0.5: Tercapai
# Target MAE < 30: Tidak Tercapai

# %%
#EXERCISE 1
# SIMPLE LINEAR REGGRESION
#menyiapkan data utk simple linear regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#menyiapkan data utk simple linear regression
X_slr = df[['JarakTempuh']]
y = df['Harga']
print("Fitur (X) utk SLR:")
display(X_slr.head())
print("\nTarget (y):")
display(y.head())

#pembagian data training (80%) dan data testing (20%)
X_train_slr, X_test_slr, y_train, y_test = train_test_split(X_slr, y, test_size=0.2, random_state=42)
print("data train shape X:", X_train_slr.shape)
print("test data shape X:", X_test_slr.shape)
print("data train shape y:", y_train.shape)
print("test data shape y:", y_test.shape)

# membangun model SLR dan melatih model SLR menggunakan data training
model_slr = LinearRegression()
model_slr.fit(X_train_slr, y_train)

#mengindetifikasikan parameter model SLR
intercept_slr = model_slr.intercept_
coef_slr = model_slr.coef_[0]

#evakuasi model SLR
y_pred_slr = model_slr.predict(X_test_slr)
mae_slr = mean_absolute_error(y_test, y_pred_slr)
mse_slr = mean_squared_error(y_test, y_pred_slr)
rmse_slr = np.sqrt(mse_slr)
r2_slr = r2_score(y_test, y_pred_slr)
print("\nEvaluation metrics for SLR model in test data:")
print(f"Mean Absolute Error (MAE):, {mae_slr:.2f} millions rupiah")
print(f"Mean Squared Error (MSE):, {mse_slr:.2f} millions rupiah")
print(f"Root Mean Squared Error (RMSE):, {rmse_slr:.2f}")
print(f"R-squared (R2):, {r2_slr:.2f}")

#bandingkan dgn target
print("\ncompare with target :")
print(f"Target R kuadrat > 0.5 : {'accomplished' if r2_slr > 0.5 else 'not accomplished'}")
print(f"Target MAE > 0.5 : {'accomplished' if mae_slr > 30 else 'not accomplished'}")

#visualisasi hasil prediksi (SLR)
plt.figure(figsize=(10, 6))
plt.scatter(X_test_slr, y_test, alpha = 0.7, label='Actual data')
plt.plot(X_test_slr, y_pred_slr, color='red', linewidth=2, label='Predicted line')
plt.title('Result Prediction SLR : Mileage vs Price (Test Data)')
plt.xlabel('Mileage (in meters)')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(x=y_test, y=y_pred_slr)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Prediction Price (SLR)')
plt.xlabel('Actual Price (in IDR)')
plt.ylabel('Predicted Price (in IDR)')

plt.grid(True)
plt.show()



# PRATIKKUM MULTI LINEAR REGGRESION
#menentukan data utk MLR
year = 2025
df['Usia'] = year - df['Tahun']
features_mlr = ['JarakTempuh','Harga','Usia']
X_mlr = df[features_mlr]
X_train_mlr, X_test_mlr, y_train, y_test = train_test_split(X_mlr, y, test_size=0.2, random_state=42)

#membagi data training dan data testing
print(f"data train shape X_mlr: {X_train_mlr.shape}")
print(f"test data shape X_mlr: {X_test_mlr.shape}")

#d.	Identifikasi Parameter Model MLR:
intercept_mlr = model_mlr.intercept_
coeffs_mlr = model_mlr.coef_
print("\nintercept (βo):, {intercept_mlr:.2f}")
#tampilkan koefisien dlm dataframe agar mudah dibaca
coeffs_df = pd.DataFrame(coeffs_mlr, index=features_mlr, columns=['Koefisien (β)'])
print("\ncoefficient feature:")
display(coeffs_df)
print(f"\nInterpretation (example for 'Price'): ")
print(f"assuming constant distance traveled and Car Age,")
if 'JarakTempuh' in coeffs_df.index :
  usia_coef = coeffs_df.loc['Usia','Koefisien (β)']
  print(f"for every additional year of age, the price of the car is predicted to decrease by {usia_coef:.2f} millions rupiahs")
else:
  print("Car age coefficient not found in the model.")
# Out:
# Fitur (X) utk SLR:
#    JarakTempuh
# 0        75000
# 1        60000
# 2        90000
# 3       110000
# 4        65000
# Target (y):
# 0    145
# 1    155
# 2    130
# 3    240
# 4    140
# Name: Harga, dtype: int64
# data train shape X: (57, 1)
# test data shape X: (15, 1)
# data train shape y: (57,)
# test data shape y: (15,)
#
# Evaluation metrics for SLR model in test data:
# Mean Absolute Error (MAE):, 75.16 millions rupiah
# Mean Squared Error (MSE):, 8944.60 millions rupiah
# Root Mean Squared Error (RMSE):, 94.58
# R-squared (R2):, -0.19
#
# compare with target :
# Target R kuadrat > 0.5 : not accomplished
# Target MAE > 0.5 : accomplished
# data train shape X_mlr: (57, 3)
# test data shape X_mlr: (15, 3)
#
# intercept (βo):, {intercept_mlr:.2f}
#
# coefficient feature:
#              Koefisien (β)
# JarakTempuh      -0.007544
# Harga            90.991112
# Usia              0.254028
# Interpretation (example for 'Price'):
# assuming constant distance traveled and Car Age,
# ...

# %%
#EXERCISE 2
# SIMPLE LINEAR REGGRESION PRATICUM
#menyiapkan data utk simple linear regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')#ignore the warnings

#setting agar plot tampil inline
# %matplotlib inline
#setting style plot(opsional)
plt.style.use('seaborn-v0_8-darkgrid')
url_data = '/content/harga_mobil_bekas.csv'
df = pd.read_csv(url_data)

#menyiapkan data utk simple linear regression
X_slr = df[['JarakTempuh']]
y = df['Harga']

#pembagian data training (80%) dan data testing (20%)
X_train_slr, X_test_slr, y_train, y_test = train_test_split(X_slr, y, test_size=0.2, random_state=42)

# membangun model SLR dan melatih model SLR menggunakan data training
model_slr = LinearRegression()
model_slr.fit(X_train_slr, y_train)

#mengindetifikasikan parameter model SLR
intercept_slr = model_slr.intercept_
coef_slr = model_slr.coef_[0]

#evakuasi model SLR
y_pred_slr = model_slr.predict(X_test_slr)
mae_slr = mean_absolute_error(y_test, y_pred_slr)
mse_slr = mean_squared_error(y_test, y_pred_slr)
rmse_slr = np.sqrt(mse_slr)
r2_slr = r2_score(y_test, y_pred_slr)



# PRATIKKUM MULTI LINEAR REGGRESION
#menentukan data utk MLR
year = 2025
df['Usia'] = year - df['Tahun']
features_mlr = ['JarakTempuh','Harga','Usia']
X_mlr = df[features_mlr]
X_train_mlr, X_test_mlr, y_train, y_test = train_test_split(X_mlr, y, test_size=0.2, random_state=42)

#d.	Identifikasi Parameter Model MLR:
intercept_mlr = model_mlr.intercept_
coeffs_mlr = model_mlr.coef_

#tampilkan koefisien dlm dataframe agar mudah dibaca
coeffs_df = pd.DataFrame(coeffs_mlr, index=features_mlr, columns=['Koefisien (β)'])

print("\nPerbandingan Performa Model:")
print(f"{'':<15}| {'SLR (Price)':<12}| {'MLR (Car Age, Price, Mileage)'}")
print(f"{'-'*15}|{'-'*13}|{'-'*26}")
print(f"{'R²':<15}| {r2_slr:.3f}<12| {r2_mlr:.3f}")
print(f"{'MAE (millions)':<15}| {mae_slr:.2f}<12| {mae_mlr:.2f}")
print(f"{'RMSE (millions)':<15}| {rmse_slr:.2f}<12| {rmse_mlr:.2f}")

print("\nAnalisis:")
if r2_mlr > r2_slr and rmse_mlr < rmse_slr:
    print("Model MLR menunjukkan performa yang lebih baik daripada SLR.")
    print(f"Target R² > 0.5: {'Acomplished' if r2_mlr > 0.5 else 'Unacomplished'}")
    print(f"Target MAE < 30: {'Acomplished' if mae_mlr < 30 else 'Unacomplished'}")
else:
    print("Penambahan fitur pada MLR tidak secara signifikan meningkatkan performa dibandingkan SLR, atau bahkan memperburuk.")
    print("Perlu dianalisis lebih lanjut (mungkin ada multikolinearitas atau fitur tidak relevan).")

plt.figure(figsize=(8, 5))
sns.scatterplot(x=y_test, y=y_pred_mlr)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Prediction Price (SLR)')
plt.xlabel('Actual Price (in IDR)')
plt.ylabel('Predicted Price (in IDR)')
plt.grid(True)
plt.show()
# Out:
# Perbandingan Performa Model:
#                | SLR (Price) | MLR (Car Age, Price, Mileage)
# ---------------|-------------|--------------------------
# R²             | -0.191<12| 0.748
# MAE (millions) | 75.16<12| 36.89
# RMSE (millions)| 94.58<12| 43.55
#
# Analisis:
# Model MLR menunjukkan performa yang lebih baik daripada SLR.
# Target R² > 0.5: Acomplished
# Target MAE < 30: Unacomplished
